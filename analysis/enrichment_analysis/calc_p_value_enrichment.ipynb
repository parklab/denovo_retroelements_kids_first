# %%
#####pLI>=0.9
####SVA
1-ppois(9, lambda = 4.695800)

####Alu
1-ppois(14, lambda = 12.771500)

####L1
1-ppois(2, lambda = 4.075500)
# Out:
# [1] 0.02208828
# [1] 0.3017621
# [1] 0.7727519

# %%
#####exonic
####SVA
1-ppois(3, lambda = 0.941200)

####Alu
1-ppois(6, lambda = 2.590800)

####L1
1-ppois(0, lambda = 0.817800)
# Out:
# [1] 0.01559273
# [1] 0.01687868
# [1] 0.5585983
